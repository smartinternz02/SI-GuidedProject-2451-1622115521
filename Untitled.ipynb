# %%
import numpy as np
import pandas as pd
import matplotlib as plt
from sklearn.preprocessing import LabelEncoder
import pickle

# %%
df = pd.read_csv(r"D:\autos.csv", header=0, sep=',', encoding='Latin1',)

# %%
print(df.seller.value_counts())
# Out:
# privat        371525
# gewerblich         3
# Name: seller, dtype: int64

# %%
df[df.seller != 'gewerblich']
df=df.drop('seller',1)

# %%
print(df.offerType.value_counts())
# Out:
# Angebot    371516
# Gesuch         12
# Name: offerType, dtype: int64

# %%
df[df.offerType !='Gesuch']
df=df.drop('offerType',1)

# %%
print(df.shape)
df = df[(df.powerPS > 50) & (df.powerPS < 900)]
print(df.shape)
df = df[(df.yearOfRegistration >= 1950) & (df.yearOfRegistration < 2017)]
print(df.shape)
# Out:
# (371528, 18)
# (319709, 18)
# (309171, 18)

# %%
df.drop(['name','abtest','dateCrawled','nrOfPictures','lastSeen','postalCode','dateCreated'], axis='columns', inplace = True)

# %%
new_df = df.copy()
new_df = new_df.drop_duplicates(['price','vehicleType','yearOfRegistration','gearbox','powerPS','model','kilometer','monthOfRegistration','fuelType','notRepairedDamage'])

# %%
new_df.gearbox.replace(('manuell', 'automatik'), ('manual','automatic'), inplace=True)
new_df.fuelType.replace(('benzin','andere','elektro'),('petrol','others','electric'),inplace=True)
new_df.vehicleType.replace(('kleinwagen','cabrio','kombi','andere'),('snall car','convertible','combination','others'),inplace=True)
new_df.notRepairedDamage.replace(('ja','nein'),('Yes','No'),inplace=True)

# %%
new_df = new_df[(new_df.price >= 100) & (new_df.price <=150000)]

# %%
new_df['notRepairedDamage'].fillna(value='not-declared', inplace=True)
new_df['fuelType'].fillna(value='not-declared', inplace=True)
new_df['gearbox'].fillna(value='not-declared', inplace=True)
new_df['vehicleType'].fillna(value='not-declared', inplace=True)
new_df['model'].fillna(value='not-declared', inplace=True)

# %%
new_df.to_csv("autos_preprocessed.csv")

# %%
labels = ['gearbox','notRepairedDamage','model','brand','fuelType','vehicleType']

# %%
mapper = {}
for i in labels:
    mapper[i] = LabelEncoder()
    mapper[i].fit(new_df[i])
    tr = mapper[i].transform(new_df[i])
    np.save(str('classes'+i+'.npy'),mapper[i].classes_)
    print(i,":",mapper[i])
    new_df.loc[:,i + '_labels'] = pd.Series(tr, index=new_df.index)
# Out:
# gearbox : LabelEncoder()
# notRepairedDamage : LabelEncoder()
# model : LabelEncoder()
# brand : LabelEncoder()
# fuelType : LabelEncoder()
# vehicleType : LabelEncoder()

# %%
labeled = new_df[['price','yearOfRegistration','powerPS','kilometer','monthOfRegistration'] + [x+"_labels" for x in labels]]
print(labeled.columns)
# Out:
# Index(['price', 'yearOfRegistration', 'powerPS', 'kilometer',
#        'monthOfRegistration', 'gearbox_labels', 'notRepairedDamage_labels',
#        'model_labels', 'brand_labels', 'fuelType_labels',
#        'vehicleType_labels'],
#       dtype='object')

# %%
Y = labeled.iloc[:,0].values
X = labeled.iloc[:,1:].values

# %%
Y = Y.reshape(-1,1)

# %%
from sklearn.model_selection import cross_val_score, train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state = 3)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
regressor = RandomForestRegressor(n_estimators=1000,max_depth=10,random_state=34)

# %%
regressor.fit(X_train, np.ravel(Y_train,order='C'))
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=10,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=1000,
#                       n_jobs=None, oob_score=False, random_state=34, verbose=0,
#                       warm_start=False)

# %%
y_pred = regressor.predict(X_test)
print(r2_score(Y_test,y_pred))
# Out:
# 0.834527626497731

# %%
filename = 'resale_model.sav'
pickle.dump(regressor, open(filename, 'wb'))

# %%
df.head()
# Out:
#    price vehicleType  yearOfRegistration    gearbox  powerPS  model  \
# 1  18300       coupe                2011    manuell      190    NaN
# 2   9800         suv                2004  automatik      163  grand
# 3   1500  kleinwagen                2001    manuell       75   golf
# 4   3600  kleinwagen                2008    manuell       69  fabia
# 5    650   limousine                1995    manuell      102    3er
#
#    kilometer  monthOfRegistration fuelType       brand notRepairedDamage
# 1     125000                    5   diesel        audi                ja
# 2     125000                    8   diesel        jeep               NaN
# 3     150000                    6   benzin  volkswagen              nein
# 4      90000                    7   diesel       skoda              nein
# 5     150000                   10   benzin         bmw                ja

# %%
df.tail()
# Out:
#         price vehicleType  yearOfRegistration    gearbox  powerPS  \
# 371520   3200   limousine                2004    manuell      225
# 371524   1199      cabrio                2000  automatik      101
# 371525   9200         bus                1996    manuell      102
# 371526   3400       kombi                2002    manuell      100
# 371527  28990   limousine                2013    manuell      320
#
#               model  kilometer  monthOfRegistration fuelType       brand  \
# 371520         leon     150000                    5   benzin        seat
# 371524       fortwo     125000                    3   benzin       smart
# 371525  transporter     150000                    3   diesel  volkswagen
# 371526         golf     150000                    6   diesel  volkswagen
# 371527      m_reihe      50000                    8   benzin         bmw
#
#        notRepairedDamage
# 371520                ja
# 371524              nein
# 371525              nein
# 371526               NaN
# 371527              nein

# %%
df
# Out:
#         price vehicleType  yearOfRegistration    gearbox  powerPS  \
# 1       18300       coupe                2011    manuell      190
# 2        9800         suv                2004  automatik      163
# 3        1500  kleinwagen                2001    manuell       75
# 4        3600  kleinwagen                2008    manuell       69
# 5         650   limousine                1995    manuell      102
# 6        2200      cabrio                2004    manuell      109
# 8       14500         bus                2014    manuell      125
# 9         999  kleinwagen                1998    manuell      101
# 10       2000   limousine                2004    manuell      105
# 11       2799       kombi                2005    manuell      140
# 12        999       kombi                1995    manuell      115
# 13       2500       kombi                2004    manuell      131
# 14      17999         suv                2011    manuell      190
# 16        300         NaN                2016        NaN       60
# 17       1750  kleinwagen                2004  automatik       75
# 18       7550         bus                2007    manuell      136
# 19       1850         bus                2004    manuell      102
# 20      10400       coupe                2009    manuell      160
# 21       3699   limousine                2002  automatik      231
# 24        500   limousine                1990    manuell      118
# 25       2500       kombi                2002  automatik      193
# 27       6900   limousine                2008    manuell       99
# 29        690  kleinwagen                2003    manuell       60
# 30       3300   limousine                1995  automatik      113
# 31        899         NaN                2016    manuell       60
# 33      18000   limousine                2007  automatik      218
# 34       3500   limousine                2004  automatik      122
# 35        350         NaN                2016    manuell       75
# 36       1600      andere                1991    manuell       75
# 38      11900      andere                2002    manuell      129
# ...       ...         ...                 ...        ...      ...
# 371488   2999       coupe                2003    manuell      143
# 371490  13850       kombi                2012    manuell      156
# 371491   3200   limousine                2002    manuell      116
# 371494  11500   limousine                2004  automatik      445
# 371496   3850      cabrio                2006    manuell      108
# 371497   4900       kombi                2008    manuell      116
# 371498    699   limousine                1999    manuell      101
# 371499    600  kleinwagen                1998    manuell       54
# 371500  20400   limousine                2014  automatik      150
# 371501   3900         bus                2003  automatik      174
# 371502   1600       kombi                1998    manuell      125
# 371503   1700  kleinwagen                1999    manuell       68
# 371505    800       kombi                2000    manuell      101
# 371506   5900   limousine                2006    manuell      105
# 371507   5999       kombi                2005    manuell      140
# 371508   1400   limousine                2001    manuell      125
# 371509   1900         NaN                2000    manuell      110
# 371510   6500   limousine                2003  automatik      145
# 371511   1999   limousine                1997    manuell      150
# 371512   5000   limousine                2003  automatik      260
# 371513   4400   limousine                2008    manuell      105
# 371514    999      cabrio                2000    manuell       95
# 371515   1690       kombi                2004    manuell       55
# 371517   7900   limousine                2010    manuell      140
# 371519   5250         NaN                2016  automatik      150
# 371520   3200   limousine                2004    manuell      225
# 371524   1199      cabrio                2000  automatik      101
# 371525   9200         bus                1996    manuell      102
# 371526   3400       kombi                2002    manuell      100
# 371527  28990   limousine                2013    manuell      320
#
#               model  kilometer  monthOfRegistration fuelType          brand  \
# 1               NaN     125000                    5   diesel           audi
# 2             grand     125000                    8   diesel           jeep
# 3              golf     150000                    6   benzin     volkswagen
# 4             fabia      90000                    7   diesel          skoda
# 5               3er     150000                   10   benzin            bmw
# 6           2_reihe     150000                    8   benzin        peugeot
# 8             c_max      30000                    8   benzin           ford
# 9              golf     150000                    0      NaN     volkswagen
# 10          3_reihe     150000                   12   benzin          mazda
# 11           passat     150000                   12   diesel     volkswagen
# 12           passat     150000                   11   benzin     volkswagen
# 13           passat     150000                    2      NaN     volkswagen
# 14           navara      70000                    3   diesel         nissan
# 16             polo     150000                    0   benzin     volkswagen
# 17           twingo     150000                    2   benzin        renault
# 18            c_max     150000                    6   diesel           ford
# 19         a_klasse     150000                    1   benzin  mercedes_benz
# 20         scirocco     100000                    4   benzin     volkswagen
# 21              5er     150000                    7   benzin            bmw
# 24           andere     150000                   10   benzin  mercedes_benz
# 25              5er     150000                    9   diesel            bmw
# 27            civic      60000                   11   benzin          honda
# 29            punto     150000                    3   benzin           fiat
# 30         e_klasse     150000                    1   diesel  mercedes_benz
# 31             clio     150000                    6   benzin        renault
# 33              3er      20000                    5   benzin            bmw
# 34         e_klasse     150000                   11   diesel  mercedes_benz
# 35             golf     150000                    4   benzin     volkswagen
# 36           kadett      70000                    0      NaN           opel
# 38           andere     150000                   11   diesel     volkswagen
# ...             ...        ...                  ...      ...            ...
# 371488       andere     150000                    3   benzin  mercedes_benz
# 371490       accord     125000                   10   benzin          honda
# 371491       passat     150000                    4      lpg     volkswagen
# 371494          7er     125000                    0   benzin            bmw
# 371496      2_reihe     125000                    2      NaN        peugeot
# 371497        astra     150000                    2   benzin           opel
# 371498       vectra     150000                    3   benzin           opel
# 371499        corsa     150000                    1   benzin           opel
# 371500         golf      30000                    9   benzin     volkswagen
# 371501      voyager     150000                    7   benzin       chrysler
# 371502           a4     150000                    2   benzin           audi
# 371503        justy      70000                   11   benzin         subaru
# 371505        astra     150000                   11   benzin           opel
# 371506         golf     150000                    9   diesel     volkswagen
# 371507           a4     150000                    4   diesel           audi
# 371508        astra     150000                    2   benzin           opel
# 371509          NaN     150000                    7      NaN     volkswagen
# 371510     e_klasse     150000                    3   diesel  mercedes_benz
# 371511           a3     150000                   12   benzin           audi
# 371512     e_klasse     150000                   12   diesel  mercedes_benz
# 371513         leon     150000                    7   diesel           seat
# 371514       megane     150000                    4   benzin        renault
# 371515        fabia     150000                    4   benzin          skoda
# 371517         golf     150000                    7   diesel     volkswagen
# 371519          159     150000                   12      NaN     alfa_romeo
# 371520         leon     150000                    5   benzin           seat
# 371524       fortwo     125000                    3   benzin          smart
# 371525  transporter     150000                    3   diesel     volkswagen
# 371526         golf     150000                    6   diesel     volkswagen
# 371527      m_reihe      50000                    8   benzin            bmw
#
#        notRepairedDamage
# 1                     ja
# 2                    NaN
# 3                   nein
# 4                   nein
# 5                     ja
# 6                   nein
# 8                    NaN
# 9                    NaN
# 10                  nein
# 11                    ja
# 12                   NaN
# 13                  nein
# 14                  nein
# 16                   NaN
# 17                  nein
# 18                  nein
# 19                  nein
# 20                  nein
# 21                  nein
# 24                    ja
# 25                    ja
# 27                  nein
# 29                  nein
# 30                  nein
# 31                   NaN
# 33                  nein
# 34                  nein
# 35                  nein
# 36                   NaN
# 38                  nein
# ...                  ...
# 371488                ja
# 371490              nein
# 371491              nein
# 371494               NaN
# 371496              nein
# 371497              nein
# 371498               NaN
# 371499              nein
# 371500              nein
# 371501              nein
# 371502              nein
# 371503              nein
# 371505                ja
# 371506              nein
# 371507               NaN
# 371508              nein
# 371509              nein
# 371510              nein
# 371511              nein
# 371512                ja
# 371513              nein
# 371514               NaN
# 371515               NaN
# 371517              nein
# 371519              nein
# 371520                ja
# 371524              nein
# 371525              nein
# 371526               NaN
# 371527              nein
#
# [309171 rows x 11 columns]

# %%
new_df.head()
# Out:
#    price vehicleType  yearOfRegistration    gearbox  powerPS         model  \
# 1  18300       coupe                2011     manual      190  not-declared
# 2   9800         suv                2004  automatic      163         grand
# 3   1500   snall car                2001     manual       75          golf
# 4   3600   snall car                2008     manual       69         fabia
# 5    650   limousine                1995     manual      102           3er
#
#    kilometer  monthOfRegistration fuelType       brand notRepairedDamage  \
# 1     125000                    5   diesel        audi               Yes
# 2     125000                    8   diesel        jeep      not-declared
# 3     150000                    6   petrol  volkswagen                No
# 4      90000                    7   diesel       skoda                No
# 5     150000                   10   petrol         bmw               Yes
#
#    gearbox_labels  notRepairedDamage_labels  model_labels  brand_labels  \
# 1               1                         1           162             1
# 2               0                         2           118            14
# 3               1                         0           117            38
# 4               1                         0           102            31
# 5               1                         1            11             2
#
#    fuelType_labels  vehicleType_labels
# 1                1                   3
# 2                1                   8
# 3                7                   7
# 4                1                   7
# 5                7                   4
